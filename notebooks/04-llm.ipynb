# %%
import os

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_deepseek import ChatDeepSeek

llm = ChatDeepSeek(model="deepseek-chat")
response = llm.invoke("Hola como estas?")

response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ¡Hola! Estoy muy bien, gracias por preguntar. ¿Y tú, cómo estás?
#
# Es un gusto saludarte. Puedo ayudarte con una gran variedad de cosas: responder preguntas, explicar conceptos, ayudarte con textos, traducir, resolver problemas... ¿En qué puedo colaborarte hoy? 😊
